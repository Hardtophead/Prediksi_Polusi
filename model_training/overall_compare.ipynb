# %%
import pandas as pd

# %%
results = pd.read_csv('results_overall_simple.csv')

results
# Out:
#               Model       MAE       RMSE    MAPE(%)        R2  Accuracy(%)
# 0  NaivePersistence  7.256501  16.943109  13.984277  0.988962    86.015723
# 1          CNN_LSTM  9.573442  17.718961  28.291024  0.987928    71.708976
# 2               GRU  9.069550  18.741582  15.588940  0.986495    84.411060
# 3             DENSE  9.830869  19.266972  20.048764  0.985727    79.951236

# %%
results_per_feature = pd.read_csv('results_per_feature_simple.csv')

results_per_feature
# Out:
#                Model Feature        MAE       RMSE    MAPE(%)        R2  \
# 0   NaivePersistence   PM2.5  10.146816  15.719890  22.497837  0.681885
# 1   NaivePersistence    PM10  18.226551  30.007501  26.073426  0.558762
# 2   NaivePersistence      CO   0.293064   0.567741   7.277447  0.687984
# 3   NaivePersistence     CO2   0.359572   0.623180   0.088400  0.839044
# 4                GRU   PM2.5  12.785861  18.023707  24.462491  0.581810
# 5                GRU    PM10  21.738219  32.822958  26.415104  0.472079
# 6                GRU      CO   0.460469   0.677421  11.160316  0.555785
# 7                GRU     CO2   1.293652   1.525835   0.317848  0.035073
# 8           CNN_LSTM   PM2.5  14.279663  18.031936  41.856028  0.581428
# 9           CNN_LSTM    PM10  21.883436  30.446753  42.339733  0.545750
# 10          CNN_LSTM      CO   1.138405   1.365340  28.724803 -0.804504
# 11          CNN_LSTM     CO2   0.992264   1.351576   0.243533  0.242888
# ...
